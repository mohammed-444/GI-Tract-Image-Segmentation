# %%
from Utils.Data_processing import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
history_1 = pd.read_csv('csv/history_effientNet.csv')
history_2 = pd.read_csv('csv/history_omar.csv')
history_2.rename(columns={'jacard_coef': 'dice_coef', 'val_jacard_coef': 'val_dice_coef'}, inplace=True)

# %%
history_1
# Out:
#     Unnamed: 0      loss  dice_coef  f1-score  f2-score  precision    recall  \
# 0            0  0.211861   0.661043  0.660786  0.685437   0.639343  0.727347
# 1            1  0.104080   0.824013  0.827217  0.832558   0.821716  0.837096
# 2            2  0.089421   0.849136  0.852420  0.856797   0.847492  0.860349
# 3            3  0.080251   0.864552  0.867506  0.871451   0.862735  0.874560
# 4            4  0.075872   0.871973  0.875014  0.878549   0.870570  0.881288
# 5            5  0.071900   0.878588  0.881332  0.884517   0.877240  0.886961
# 6            6  0.068062   0.884992  0.887646  0.890564   0.883817  0.892779
# 7            7  0.066398   0.887783  0.890374  0.892857   0.887273  0.894783
# 8            8  0.062860   0.893693  0.896198  0.898601   0.892976  0.900405
# 9            9  0.062272   0.894673  0.897083  0.899455   0.893949  0.901248
# 10          10  0.060062   0.898338  0.900662  0.902962   0.897556  0.904684
# ...

# %%
# history_1 = history_1.rename(columns={history_1.columns[0]: 'epoch'})

# %%
history_1.columns
# Out:
# Index(['Unnamed: 0', 'loss', 'dice_coef', 'f1-score', 'f2-score', 'precision',
#        'recall', 'iou_score', 'val_loss', 'val_dice_coef', 'val_f1-score',
#        'val_f2-score', 'val_precision', 'val_recall', 'val_iou_score'],
#       dtype='object')

# %%
animate_plot(history_1, Plot_mode='loss', y_range_loss_range=1, delay=100,)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'NoneType'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 animate_plot(history_1, Plot_mode='loss', y_range_loss_range=1, delay=100,)
#
# File c:\Users\DELL\OneDrive\Desktop\GitHub Projects\GI-Tract-Image-Segmentation\Utils\Utils.py:30, in animate_plot(hisotry, Plot_mode, y_range_loss_range, delay, Darmode, Animate, streamlit, SHOW_GRID)
#      28     y_range_max_range = y_range_loss_range
#      29 print(type(hisotry))
# ---> 30 hisotry[trace1_col] = hisotry[trace1_col].apply(lambda x: round(x, 4))
#      31 hisotry[trace2_col] = hisotry[trace2_col].apply(lambda x: round(x, 4))
#      33 trace1 = go.Scatter(
#      34     x=hisotry[hisotry.columns[0]] , y=hisotry[trace1_col], name='train_'+trace1_col
#      35 )
#
# TypeError: 'NoneType' object is not subscriptable

# %%
history_2
# Out:
#     epoch      loss  accuracy  dice_coef  iou_score  f1-score  f2-score  \
# 0       1  0.340756  0.463306   0.284412   0.267597  0.395852  0.415931
# 1       2  0.188805  0.570686   0.519202   0.519984  0.679452  0.687161
# 2       3  0.151616  0.530027   0.595168   0.600142  0.746177  0.750427
# 3       4  0.132279  0.600216   0.637639   0.643483  0.779606  0.782552
# 4       5  0.123848  0.637006   0.657069   0.662845  0.794064  0.796470
# 5       6  0.116419  0.644400   0.674663   0.680771  0.807056  0.809664
# 6       7  0.111906  0.628990   0.685200   0.691699  0.815076  0.817785
# 7       8  0.108739  0.683015   0.693027   0.699700  0.820725  0.823155
# 8       9  0.105769  0.645322   0.700103   0.705929  0.825123  0.827135
# 9      10  0.102560  0.716472   0.707723   0.713853  0.830694  0.833062
# 10     11  0.100441  0.719926   0.712983   0.718928  0.834161  0.836388
# 11     12  0.099581  0.736407   0.715271   0.721173  0.835723  0.837427
# ...

# %%
animate_plot(history_2, Plot_mode='DICE', title='Dice Coef After TL', y_range_loss_range=2, delay=100)
